# %%
from keras.models import Sequential
from keras.layers import Dense
import  matplotlib.pyplot as plt
import  pandas as pd
#read in data
diabetes = pd.read_csv("diabetes.csv")

print(diabetes.head())

print("dimension of diabetes data: {}".format(diabetes.shape)) 
print(diabetes.groupby('Outcome').size())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# dimension of diabetes data: (768, 9)
# Outcome
# 0    500
# 1    268
# dtype: int64

# %%
#数据划分
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y = train_test_split(diabetes.loc[:, diabetes.columns != 'Outcome'],
    diabetes['Outcome'], stratify=diabetes['Outcome'],
    random_state=66)

# %%
#模型搭建
model = Sequential()
model.add(Dense(12,input_dim=8,activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy']
             )

# %%
history = model.fit(train_x,train_y,epochs=150,batch_size=10,validation_data=(test_x,test_y))
# Out:
# Epoch 1/150
# 58/58 [==============================] - 1s 10ms/step - loss: 7.9923 - accuracy: 0.4410 - val_loss: 4.0188 - val_accuracy: 0.5729
# Epoch 2/150
# 58/58 [==============================] - 0s 5ms/step - loss: 2.1921 - accuracy: 0.5747 - val_loss: 1.7924 - val_accuracy: 0.5990
# Epoch 3/150
# 58/58 [==============================] - 0s 6ms/step - loss: 1.3528 - accuracy: 0.5868 - val_loss: 1.2546 - val_accuracy: 0.5104
# Epoch 4/150
# 58/58 [==============================] - 0s 5ms/step - loss: 1.1415 - accuracy: 0.5556 - val_loss: 0.9894 - val_accuracy: 0.5729
# Epoch 5/150
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9627 - accuracy: 0.5642 - val_loss: 0.8593 - val_accuracy: 0.6406
# Epoch 6/150
# 58/58 [==============================] - 0s 5ms/step - loss: 0.8693 - accuracy: 0.6024 - val_loss: 0.7450 - val_accuracy: 0.5938
# Epoch 7/150
# ...

# %%
epochs =range(1,len(loss)+1)

history_dict = history.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

plt.plot(epochs,loss,'bo',label='loss')
plt.plot(epochs,val_loss,'b',label='Validation loss')
plt.title("Training and validation loss")
plt.ylabel("Loss")
plt.xlabel("Epoches")
plt.legend()
# plt.show()
plt.savefig("image/loss")


plt.clf()
acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']
plt.plot(epochs,acc,'bo',label='accuracy')
plt.plot(epochs,val_acc,'b',label='Validation acc')
plt.title("Training and validation accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoches")
plt.legend()
# plt.show()

plt.savefig("image/accuracy")
